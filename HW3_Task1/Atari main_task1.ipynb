# %% [markdown]
# ## 1. Read Me
# **Run first cell :** install dependencies
#
# **Run second cell :** install files and local environment on the VM, choose which task you want to run by setting task_1 or task_2 value to true
#
# **Run third cell :** try diferent init of the agent. When one is found -> the agent is trained

# %%
# Dependencies

# !pip install torch numpy git+https://github.com/cs4246/gym-grid-driving.git
# !pip install -U -q PyDrive
# Out:
# Collecting git+https://github.com/cs4246/gym-grid-driving.git
#   Cloning https://github.com/cs4246/gym-grid-driving.git to /tmp/pip-req-build-uxbemkad
#   Running command git clone -q https://github.com/cs4246/gym-grid-driving.git /tmp/pip-req-build-uxbemkad
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.18.2)
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from gym-grid-driving==0.0.1) (0.17.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->gym-grid-driving==0.0.1) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->gym-grid-driving==0.0.1) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym->gym-grid-driving==0.0.1) (1.12.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->gym-grid-driving==0.0.1) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->gym-grid-driving==0.0.1) (0.16.0)
# Building wheels for collected packages: gym-grid-driving
#   Building wheel for gym-grid-driving (setup.py) ... done
#   Created wheel for gym-grid-driving: filename=gym_grid_driving-0.0.1-cp36-none-any.whl size=8623 sha256=7518455f1c8633e725bd6dc776d4ecd3462e5466324948fdadd80197ac1eca53
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t3to2rfa/wheels/e1/30/f2/157c0938ab9bfe9c10c29c9fcab8392f587c9d141f215b67ca
# Successfully built gym-grid-driving
# Installing collected packages: gym-grid-driving
# Successfully installed gym-grid-driving-0.0.1

# %%
# Authentification / Initialization of workspace 

import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create repo folders 

task_1 = False
# If False task_2 workplace will be downloaded

if task_1:
  number_task = 1
else:
  number_task = 2

root = '/content'
local_download = os.path.join(root,'HW3_Task{}'.format(number_task))

if not(os.path.exists(local_download)): 
  os.mkdir(local_download)

local_download_agent = os.path.join(local_download,'agent')

if not(os.path.exists(local_download_agent)): 
  os.mkdir(local_download_agent)

  # Download files 


def download_list(file_list,path_name):
    
  error_l = [];
    
  for f in file_list:
    # 3. Create & download by id.
  
    print('file found : title: %s, id: %s' % (f['title'], f['id']))
    try:
      #print('title: %s, id: %s' % (f['title'], f['id']))
      fname = os.path.join(path_name, f['title'])
      
      # Download only .py files
      if fname[-3:] == ".py":
        print('downloading to {}'.format(fname))
        f_ = drive.CreateFile({'id': f['id']})
        f_.GetContentFile(fname)
      
    except:
      print("there is an error")          
      error_l.append(fname)


if task_1:
  # Initial folder
  local_download_path = local_download_agent

  # Agent files 
  file_list = drive.ListFile(
        {'q': "'1ktZR8KIIWEi8Cre92SFomSEchWleHtSu' in parents"}).GetList()

  download_list(file_list,local_download_path)


  # Initial files
  local_download_path = local_download

  file_list = drive.ListFile(
        {'q': "'1x4sJIKHA6NZ5y78AnOJeCZP8abI4gLLO' in parents"}).GetList()

  download_list(file_list,local_download_path)

else:

  # Initial folder
  local_download_path = local_download_agent

  # Agent files 
  file_list = drive.ListFile(
        {'q': "'1PUrHkG6ki4JsiXtKOtvc2vAuR6IJMnCa' in parents"}).GetList()

  download_list(file_list,local_download_path)


  # Initial files
  local_download_path = local_download

  file_list = drive.ListFile(
        {'q': "'17wsroYnRmoTt-OIzDJRrUNvVFmohBVFR' in parents"}).GetList()

  download_list(file_list,local_download_path)
# Out:
# file found : title: models.py, id: 1BW6dbcbWvmC7JbqE78269K1IXIPwtlEi
# downloading to /content/HW3_Task2/agent/models.py
# file found : title: __pycache__, id: 1OfJrkmLCYqUS8vVjJnxgeZCvQEnQSQ4J
# file found : title: env.py, id: 1bYr6NdzVOXe77n-gUac3VdGA8tnpS8HJ
# downloading to /content/HW3_Task2/agent/env.py
# file found : title: __init__.py, id: 1WO1O3RwqCpk7XdN07UUZbF6YTaj5mGGg
# downloading to /content/HW3_Task2/agent/__init__.py
# file found : title: model_last_20_05_actionR_cb_.textClipping, id: 1aESmsKWtCbxwgAAqKV9wP1eE4xDOCBFp
# file found : title: model_last_20_05_actionR_cb_8_5000.pt, id: 1FdLXoWHZQz8l5hS76ygQJXe2HWa-wLJI
# file found : title: model.pt, id: 1_hr_fysoSC6AXix1Qjqq0bBYk0KiSIcq
# file found : title: .ipynb_checkpoints, id: 14rimDklDDBO4_OqcqfbiybhzNMxQQFSm
# file found : title: ZZZ.zip, id: 1CVWs9pxeQ6FieIRMszIIfNK1my32N3Wl
# file found : title: ZZZ, id: 10kHEkPFSjAINnDqi2s5KF7PxQN9bImk3
# file found : title: try2 2, id: 1Ka1yYoo2aGsxPITkqKfBYB4AAHln0aMZ
# file found : title: try2.zip, id: 1o5hCQ_s6UkmcbRNTkR8crcNcftp1IhZ7
# file found : title: try2 2.zip, id: 1R8lmVqVxgvfuQ150WK4ZckNmfjvWmvW4
# file found : title: try2, id: 1T1A0dN0enM4yy8DmA6A7HJOFyGQS0IlX
# file found : title: A0212190W_Task2.zip, id: 1XJ9tRmPvxju3IjD76WkmINyUlYTIJvVm
# file found : title: agent, id: 1PUrHkG6ki4JsiXtKOtvc2vAuR6IJMnCa
# file found : title: setup.py, id: 1GrxqesqYqNJit3lNQABi9n3Wisa5zuir
# downloading to /content/HW3_Task2/setup.py
# file found : title: MANIFEST.in, id: 16_Iy5dYGYMUP2T9hl-OZdODIhV7dbgCf

# %%
# TASK 2

import sys
import time

import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

date_save = time.strftime("%d %H %M")
model_path = os.path.join('HW3_Task2','agent', 'model_{}_{}.pt'.format(date_save,2))
save_path = os.path.join('HW3_Task2','agent', 'model_{}_{}.pt'.format(date_save,3))

duree = 0 
nb_bad_init = 0 
# Try for 10 diferent inits

for i in range(0,1):
  debut = time.time()
  # Try an init 
  #!python3 HW3_Task2/agent/models.py --test --path=HW3_Task2/agent/model_last1_20_05_cb_8_1000.pt --savepath=HW3_Task2/agent/model_last1_20_05
  # !python3 HW3_Task2/agent/models.py --train --path=HW3_Task2/agent/model_last_21_05_cb_8_4000.pt --savepath=HW3_Task2/agent/model_last_21_05_r2
  #!python3 HW3_Task2/agent/models.py --test --path=HW3_Task2/agent/model_last_20_05_actionR_cb_8_19000.pt --savepath=HW3_Task2/agent/model_last_20_05
  #!python3 HW3_Task2/agent/testenv.py
  duree = (time.time()-debut)
  # If good init exit loop
  print(duree)
  if duree > 10000:
    break
# Out:
# cuda
# train mode
# ConvDQN(
#   (features): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(2, 2), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(2, 2), stride=(1, 1))
#     (3): ReLU()
#   )
#   (layers): Sequential(
#     (0): Linear(in_features=24576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# range change : x_min 3 x_max 6
# environment change : i_1 5 j_1 2
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.002420,	buffer size : 1046,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.001167,	buffer size : 2192,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000778,	buffer size : 3681,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 400]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000589,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 4, j: 3, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 11.046074390411377 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000476,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 600]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000401,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 700]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000347,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 800]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000306,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 900]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000273,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 4, j: 3, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 14.84691333770752 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000246,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000224,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000206,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1300]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000190,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1400]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000177,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 6, j: 3, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 19.189531564712524 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000165,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1600]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000155,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1700]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000146,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1800]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000138,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1900]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000131,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 0.0
# range change : x_min 6 x_max 10
# environment change : i_1 9 j_1 3
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000018,	buffer size : 1446,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000018,	buffer size : 3141,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000018,	buffer size : 4000,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 400]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000018,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 10, j: 5, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 26.268616437911987 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000017,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 600]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000016,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 700]	 rewards globals : 0.014 	avg rewards : 0.099,	avg loss: : 0.001354,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 800]	 rewards globals : 0.050 	avg rewards : 0.297,	avg loss: : 0.003797,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 900]	 rewards globals : 0.044 	avg rewards : 0.000,	avg loss: : 0.009497,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 6, j: 5, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 12.338403224945068 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.050 	avg rewards : 0.099,	avg loss: : 0.015325,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 1100]	 rewards globals : 0.045 	avg rewards : 0.000,	avg loss: : 0.023161,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1200]	 rewards globals : 0.050 	avg rewards : 0.099,	avg loss: : 0.024050,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 1300]	 rewards globals : 0.046 	avg rewards : 0.000,	avg loss: : 0.024025,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1400]	 rewards globals : 0.043 	avg rewards : 0.000,	avg loss: : 0.023532,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 9, j: 4, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 27.312077522277832 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 0.040 	avg rewards : 0.000,	avg loss: : 0.021968,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1600]	 rewards globals : 0.037 	avg rewards : 0.000,	avg loss: : 0.020598,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1700]	 rewards globals : 0.035 	avg rewards : 0.000,	avg loss: : 0.019389,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1800]	 rewards globals : 0.044 	avg rewards : 0.198,	avg loss: : 0.018497,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 1.9801980198019802
# [Episode 1900]	 rewards globals : 0.047 	avg rewards : 0.099,	avg loss: : 0.020630,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# range change : x_min 10 x_max 17
# environment change : i_1 10 j_1 3
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000264,	buffer size : 1114,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000311,	buffer size : 2349,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000374,	buffer size : 3811,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 400]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.000391,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 16, j: 3, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.1
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.05
# Local runtime: 19.41950559616089 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.060 	avg rewards : 0.297,	avg loss: : 0.008341,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 600]	 rewards globals : 0.050 	avg rewards : 0.000,	avg loss: : 0.016994,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 700]	 rewards globals : 0.057 	avg rewards : 0.099,	avg loss: : 0.024106,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 800]	 rewards globals : 0.050 	avg rewards : 0.000,	avg loss: : 0.024884,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 900]	 rewards globals : 0.055 	avg rewards : 0.099,	avg loss: : 0.025568,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# Test mode, runs: 100, i: 17, j: 5, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 24.010128498077393 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.060 	avg rewards : 0.099,	avg loss: : 0.024264,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 1100]	 rewards globals : 0.064 	avg rewards : 0.099,	avg loss: : 0.024153,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 1200]	 rewards globals : 0.067 	avg rewards : 0.099,	avg loss: : 0.023702,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 1300]	 rewards globals : 0.085 	avg rewards : 0.297,	avg loss: : 0.022942,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 1400]	 rewards globals : 0.079 	avg rewards : 0.000,	avg loss: : 0.022262,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 10, j: 6, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.0
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 0.0
# Local runtime: 22.57646369934082 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 0.080 	avg rewards : 0.099,	avg loss: : 0.021179,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 1600]	 rewards globals : 0.075 	avg rewards : 0.000,	avg loss: : 0.019991,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1700]	 rewards globals : 0.088 	avg rewards : 0.297,	avg loss: : 0.018998,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 1800]	 rewards globals : 0.083 	avg rewards : 0.000,	avg loss: : 0.018581,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 1900]	 rewards globals : 0.100 	avg rewards : 0.396,	avg loss: : 0.018126,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 3.9603960396039604
# range change : x_min 17 x_max 25
# environment change : i_1 20 j_1 6
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.008410,	buffer size : 1067,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.011356,	buffer size : 2029,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.066 	avg rewards : 0.198,	avg loss: : 0.016723,	buffer size : 3286,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 1.9801980198019802
# [Episode 400]	 rewards globals : 0.050 	avg rewards : 0.000,	avg loss: : 0.021016,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 25, j: 7, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 0.5
# [task_2_tmax40] 100 run(s) avg rewards : 0.6
# Point: 0.55
# Local runtime: 40.72434377670288 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.180 	avg rewards : 0.693,	avg loss: : 0.024933,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 6.9306930693069315
# [Episode 600]	 rewards globals : 0.233 	avg rewards : 0.594,	avg loss: : 0.028492,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 5.9405940594059405
# [Episode 700]	 rewards globals : 0.328 	avg rewards : 0.891,	avg loss: : 0.031710,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 8.91089108910891
# [Episode 800]	 rewards globals : 0.400 	avg rewards : 0.891,	avg loss: : 0.033387,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 8.91089108910891
# [Episode 900]	 rewards globals : 0.455 	avg rewards : 0.891,	avg loss: : 0.033799,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 8.91089108910891
# Test mode, runs: 100, i: 18, j: 6, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 2.0
# [task_2_tmax40] 100 run(s) avg rewards : 2.1
# Point: 2.05
# Local runtime: 18.44465208053589 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.480 	avg rewards : 0.693,	avg loss: : 0.033646,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 6.9306930693069315
# [Episode 1100]	 rewards globals : 0.472 	avg rewards : 0.396,	avg loss: : 0.033634,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 3.9603960396039604
# [Episode 1200]	 rewards globals : 0.458 	avg rewards : 0.297,	avg loss: : 0.033972,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 1300]	 rewards globals : 0.438 	avg rewards : 0.198,	avg loss: : 0.034884,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 1.9801980198019802
# [Episode 1400]	 rewards globals : 0.428 	avg rewards : 0.297,	avg loss: : 0.034901,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# Test mode, runs: 100, i: 20, j: 5, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 3.8
# [task_2_tmax40] 100 run(s) avg rewards : 3.4
# Point: 3.5999999999999996
# Local runtime: 27.800774574279785 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 0.473 	avg rewards : 1.089,	avg loss: : 0.035359,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 10.891089108910892
# [Episode 1600]	 rewards globals : 0.487 	avg rewards : 0.693,	avg loss: : 0.036536,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 6.9306930693069315
# [Episode 1700]	 rewards globals : 0.523 	avg rewards : 1.089,	avg loss: : 0.037951,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 10.891089108910892
# [Episode 1800]	 rewards globals : 0.583 	avg rewards : 1.584,	avg loss: : 0.039757,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 15.841584158415841
# [Episode 1900]	 rewards globals : 0.626 	avg rewards : 1.386,	avg loss: : 0.042058,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 13.861386138613863
# range change : x_min 25 x_max 30
# environment change : i_1 27 j_1 8
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.070962,	buffer size : 937,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.102692,	buffer size : 2129,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.033 	avg rewards : 0.099,	avg loss: : 0.132864,	buffer size : 3292,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# [Episode 400]	 rewards globals : 0.224 	avg rewards : 0.792,	avg loss: : 0.159907,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 7.920792079207921
# Test mode, runs: 100, i: 25, j: 5, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 1.1
# [task_2_tmax40] 100 run(s) avg rewards : 0.4
# Point: 0.75
# Local runtime: 22.574877738952637 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.339 	avg rewards : 0.792,	avg loss: : 0.183345,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 7.920792079207921
# [Episode 600]	 rewards globals : 0.366 	avg rewards : 0.495,	avg loss: : 0.202792,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 4.9504950495049505
# [Episode 700]	 rewards globals : 0.399 	avg rewards : 0.594,	avg loss: : 0.210400,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 5.9405940594059405
# [Episode 800]	 rewards globals : 0.462 	avg rewards : 0.891,	avg loss: : 0.212193,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 8.91089108910891
# [Episode 900]	 rewards globals : 0.499 	avg rewards : 0.792,	avg loss: : 0.214438,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 7.920792079207921
# Test mode, runs: 100, i: 27, j: 6, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 4.1
# [task_2_tmax40] 100 run(s) avg rewards : 4.8
# Point: 4.449999999999999
# Local runtime: 50.15574502944946 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.599 	avg rewards : 1.485,	avg loss: : 0.213535,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 14.85148514851485
# [Episode 1100]	 rewards globals : 0.772 	avg rewards : 2.475,	avg loss: : 0.214598,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 24.752475247524753
# [Episode 1200]	 rewards globals : 0.933 	avg rewards : 2.673,	avg loss: : 0.212956,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 26.732673267326735
# [Episode 1300]	 rewards globals : 0.984 	avg rewards : 1.683,	avg loss: : 0.208408,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 16.831683168316832
# [Episode 1400]	 rewards globals : 1.135 	avg rewards : 3.069,	avg loss: : 0.207333,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 30.693069306930692
# Test mode, runs: 100, i: 28, j: 2, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 6.6
# [task_2_tmax40] 100 run(s) avg rewards : 5.5
# Point: 6.05
# Local runtime: 46.32540559768677 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 1.126 	avg rewards : 0.990,	avg loss: : 0.205772,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 9.900990099009901
# [Episode 1600]	 rewards globals : 1.143 	avg rewards : 1.485,	avg loss: : 0.202949,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 14.85148514851485
# [Episode 1700]	 rewards globals : 1.170 	avg rewards : 1.683,	avg loss: : 0.200656,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 16.831683168316832
# [Episode 1800]	 rewards globals : 1.210 	avg rewards : 1.881,	avg loss: : 0.197028,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 18.81188118811881
# [Episode 1900]	 rewards globals : 1.241 	avg rewards : 1.782,	avg loss: : 0.192079,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 17.82178217821782
# range change : x_min 30 x_max 35
# environment change : i_1 31 j_1 6
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.058862,	buffer size : 1024,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.100 	avg rewards : 0.198,	avg loss: : 0.086303,	buffer size : 2295,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 1.9801980198019802
# [Episode 300]	 rewards globals : 0.199 	avg rewards : 0.396,	avg loss: : 0.118637,	buffer size : 3807,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 3.9603960396039604
# [Episode 400]	 rewards globals : 0.175 	avg rewards : 0.099,	avg loss: : 0.132403,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# Test mode, runs: 100, i: 34, j: 9, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 1.4
# [task_2_tmax40] 100 run(s) avg rewards : 1.7
# Point: 1.5499999999999998
# Local runtime: 42.787343978881836 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.220 	avg rewards : 0.396,	avg loss: : 0.148728,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 3.9603960396039604
# [Episode 600]	 rewards globals : 0.333 	avg rewards : 0.891,	avg loss: : 0.159190,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 8.91089108910891
# [Episode 700]	 rewards globals : 0.371 	avg rewards : 0.594,	avg loss: : 0.168988,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 5.9405940594059405
# [Episode 800]	 rewards globals : 0.512 	avg rewards : 1.485,	avg loss: : 0.177532,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 14.85148514851485
# [Episode 900]	 rewards globals : 0.644 	avg rewards : 1.683,	avg loss: : 0.185137,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 16.831683168316832
# Test mode, runs: 100, i: 35, j: 5, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 4.4
# [task_2_tmax40] 100 run(s) avg rewards : 6.2
# Point: 5.300000000000001
# Local runtime: 64.31293821334839 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.759 	avg rewards : 1.782,	avg loss: : 0.188028,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 17.82178217821782
# [Episode 1100]	 rewards globals : 0.908 	avg rewards : 2.376,	avg loss: : 0.188531,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 23.762376237623762
# [Episode 1200]	 rewards globals : 1.074 	avg rewards : 2.871,	avg loss: : 0.187568,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 28.71287128712871
# [Episode 1300]	 rewards globals : 1.230 	avg rewards : 3.069,	avg loss: : 0.184677,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 30.693069306930692
# [Episode 1400]	 rewards globals : 1.392 	avg rewards : 3.465,	avg loss: : 0.182041,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 34.65346534653465
# Test mode, runs: 100, i: 31, j: 9, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 1.7
# [task_2_tmax40] 100 run(s) avg rewards : 2.2
# Point: 1.9500000000000002
# Local runtime: 71.77855348587036 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 1.452 	avg rewards : 2.277,	avg loss: : 0.178332,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 22.772277227722775
# [Episode 1600]	 rewards globals : 1.574 	avg rewards : 3.366,	avg loss: : 0.173083,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 33.663366336633665
# [Episode 1700]	 rewards globals : 1.652 	avg rewards : 2.871,	avg loss: : 0.171760,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 28.71287128712871
# [Episode 1800]	 rewards globals : 1.727 	avg rewards : 2.970,	avg loss: : 0.173736,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 29.7029702970297
# [Episode 1900]	 rewards globals : 1.836 	avg rewards : 3.762,	avg loss: : 0.174348,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 37.62376237623762
# range change : x_min 35 x_max 40
# environment change : i_1 35 j_1 3
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.117586,	buffer size : 1023,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.133343,	buffer size : 2548,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.145144,	buffer size : 4000,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 400]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.161324,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 36, j: 2, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 3.1
# [task_2_tmax40] 100 run(s) avg rewards : 3.0
# Point: 3.05
# Local runtime: 32.787580251693726 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.060 	avg rewards : 0.297,	avg loss: : 0.169940,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 600]	 rewards globals : 0.150 	avg rewards : 0.594,	avg loss: : 0.176881,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 5.9405940594059405
# [Episode 700]	 rewards globals : 0.128 	avg rewards : 0.000,	avg loss: : 0.174484,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 800]	 rewards globals : 0.137 	avg rewards : 0.198,	avg loss: : 0.169642,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 1.9801980198019802
# [Episode 900]	 rewards globals : 0.133 	avg rewards : 0.099,	avg loss: : 0.161351,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 0.9900990099009901
# Test mode, runs: 100, i: 40, j: 8, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 2.5
# [task_2_tmax40] 100 run(s) avg rewards : 2.5
# Point: 2.5
# Local runtime: 68.22105264663696 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.170 	avg rewards : 0.495,	avg loss: : 0.152938,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 4.9504950495049505
# [Episode 1100]	 rewards globals : 0.182 	avg rewards : 0.297,	avg loss: : 0.145289,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 2.9702970297029703
# [Episode 1200]	 rewards globals : 0.208 	avg rewards : 0.495,	avg loss: : 0.138857,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 4.9504950495049505
# [Episode 1300]	 rewards globals : 0.269 	avg rewards : 0.990,	avg loss: : 0.135294,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 9.900990099009901
# [Episode 1400]	 rewards globals : 0.407 	avg rewards : 2.178,	avg loss: : 0.132996,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 21.782178217821784
# Test mode, runs: 100, i: 37, j: 7, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 3.1
# [task_2_tmax40] 100 run(s) avg rewards : 3.3
# Point: 3.2
# Local runtime: 65.27630758285522 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 0.546 	avg rewards : 2.475,	avg loss: : 0.132538,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 24.752475247524753
# [Episode 1600]	 rewards globals : 0.625 	avg rewards : 1.782,	avg loss: : 0.133118,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 17.82178217821782
# [Episode 1700]	 rewards globals : 0.747 	avg rewards : 2.673,	avg loss: : 0.132941,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 26.732673267326735
# [Episode 1800]	 rewards globals : 0.900 	avg rewards : 3.465,	avg loss: : 0.134090,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 34.65346534653465
# [Episode 1900]	 rewards globals : 1.015 	avg rewards : 3.069,	avg loss: : 0.135200,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 30.693069306930692
# range change : x_min 40 x_max 45
# environment change : i_1 43 j_1 5
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.117165,	buffer size : 1402,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.121218,	buffer size : 2949,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.126254,	buffer size : 4000,	epsilon : 37.4%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 400]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.127829,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 0.0, 	 r > 40 0.0
# Test mode, runs: 100, i: 41, j: 8, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 2.7
# [task_2_tmax40] 100 run(s) avg rewards : 0.1
# Point: 1.4000000000000001
# Local runtime: 93.68550562858582 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.040 	avg rewards : 0.198,	avg loss: : 0.126845,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 0.0, 	 r > 40 1.9801980198019802
# [Episode 600]	 rewards globals : 0.150 	avg rewards : 0.693,	avg loss: : 0.122829,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 0.0, 	 r > 40 6.9306930693069315
# [Episode 700]	 rewards globals : 0.285 	avg rewards : 1.089,	avg loss: : 0.119757,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 0.0, 	 r > 40 10.891089108910892
# [Episode 800]	 rewards globals : 0.437 	avg rewards : 1.485,	avg loss: : 0.117745,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 0.0, 	 r > 40 14.85148514851485
# [Episode 900]	 rewards globals : 0.610 	avg rewards : 1.980,	avg loss: : 0.118096,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 0.0, 	 r > 40 19.801980198019802
# Test mode, runs: 100, i: 43, j: 7, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 2.3
# [task_2_tmax40] 100 run(s) avg rewards : 1.7
# Point: 2.0
# Local runtime: 88.79474878311157 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 0.729 	avg rewards : 1.881,	avg loss: : 0.118008,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 0.0, 	 r > 40 18.81188118811881
# [Episode 1100]	 rewards globals : 0.745 	avg rewards : 0.990,	avg loss: : 0.116950,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 0.0, 	 r > 40 9.900990099009901
# [Episode 1200]	 rewards globals : 0.841 	avg rewards : 1.881,	avg loss: : 0.117316,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 0.0, 	 r > 40 18.81188118811881
# [Episode 1300]	 rewards globals : 0.976 	avg rewards : 2.574,	avg loss: : 0.119026,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 0.0, 	 r > 40 25.742574257425744
# [Episode 1400]	 rewards globals : 1.135 	avg rewards : 3.168,	avg loss: : 0.122254,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 0.0, 	 r > 40 31.683168316831683
# Test mode, runs: 100, i: 44, j: 7, final: False
# [task_2_tmax50] 100 run(s) avg rewards : 5.4
# [task_2_tmax40] 100 run(s) avg rewards : 2.4
# Point: 3.9000000000000004
# Local runtime: 80.4621090888977 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 1.339 	avg rewards : 4.158,	avg loss: : 0.125004,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 0.0, 	 r > 40 41.584158415841586
# [Episode 1600]	 rewards globals : 1.437 	avg rewards : 2.970,	avg loss: : 0.128990,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 0.0, 	 r > 40 29.7029702970297
# [Episode 1700]	 rewards globals : 1.546 	avg rewards : 3.366,	avg loss: : 0.133951,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 0.0, 	 r > 40 33.663366336633665
# [Episode 1800]	 rewards globals : 1.721 	avg rewards : 4.752,	avg loss: : 0.139993,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 47.524752475247524
# [Episode 1900]	 rewards globals : 1.831 	avg rewards : 3.762,	avg loss: : 0.146268,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 0.0, 	 r > 40 37.62376237623762
# range change : x_min 49 x_max 49
# environment change : i_1 49 j_1 9
# [Episode 100]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.226737,	buffer size : 1209,	epsilon : 71.9%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 200]	 rewards globals : 0.000 	avg rewards : 0.000,	avg loss: : 0.231786,	buffer size : 2946,	epsilon : 51.8%, 	 r <=40 0.0, 	 r > 40 0.0
# [Episode 300]	 rewards globals : 0.133 	avg rewards : 0.396,	avg loss: : 0.237260,	buffer size : 4000,	epsilon : 37.4%, 	 r <=40 1.9801980198019802, 	 r > 40 0.0
# [Episode 400]	 rewards globals : 0.274 	avg rewards : 0.693,	avg loss: : 0.226354,	buffer size : 4000,	epsilon : 27.1%, 	 r <=40 2.9702970297029703, 	 r > 40 0.9900990099009901
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 2.7
# [task_2_tmax40] 100 run(s) avg rewards : 0.0
# Point: 1.35
# Local runtime: 104.61848521232605 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 500]	 rewards globals : 0.419 	avg rewards : 0.990,	avg loss: : 0.216838,	buffer size : 4000,	epsilon : 19.7%, 	 r <=40 3.9603960396039604, 	 r > 40 1.9801980198019802
# [Episode 600]	 rewards globals : 0.466 	avg rewards : 0.693,	avg loss: : 0.207559,	buffer size : 4000,	epsilon : 14.4%, 	 r <=40 1.9801980198019802, 	 r > 40 2.9702970297029703
# [Episode 700]	 rewards globals : 0.642 	avg rewards : 1.683,	avg loss: : 0.207293,	buffer size : 4000,	epsilon : 10.6%, 	 r <=40 1.9801980198019802, 	 r > 40 12.871287128712872
# [Episode 800]	 rewards globals : 0.886 	avg rewards : 2.673,	avg loss: : 0.208016,	buffer size : 4000,	epsilon : 7.9%, 	 r <=40 6.9306930693069315, 	 r > 40 12.871287128712872
# [Episode 900]	 rewards globals : 1.010 	avg rewards : 2.178,	avg loss: : 0.209482,	buffer size : 4000,	epsilon : 5.9%, 	 r <=40 2.9702970297029703, 	 r > 40 15.841584158415841
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 3.6
# [task_2_tmax40] 100 run(s) avg rewards : 2.8
# Point: 3.2
# Local runtime: 76.24797129631042 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1000]	 rewards globals : 1.129 	avg rewards : 2.178,	avg loss: : 0.210727,	buffer size : 4000,	epsilon : 4.5%, 	 r <=40 4.9504950495049505, 	 r > 40 11.881188118811881
# [Episode 1100]	 rewards globals : 1.599 	avg rewards : 6.238,	avg loss: : 0.212329,	buffer size : 4000,	epsilon : 3.5%, 	 r <=40 28.71287128712871, 	 r > 40 4.9504950495049505
# [Episode 1200]	 rewards globals : 1.957 	avg rewards : 5.842,	avg loss: : 0.217553,	buffer size : 4000,	epsilon : 2.8%, 	 r <=40 25.742574257425744, 	 r > 40 6.9306930693069315
# [Episode 1300]	 rewards globals : 2.237 	avg rewards : 5.545,	avg loss: : 0.222699,	buffer size : 4000,	epsilon : 2.3%, 	 r <=40 24.752475247524753, 	 r > 40 5.9405940594059405
# [Episode 1400]	 rewards globals : 2.448 	avg rewards : 5.149,	avg loss: : 0.228804,	buffer size : 4000,	epsilon : 1.9%, 	 r <=40 25.742574257425744, 	 r > 40 0.0
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 2.5
# [task_2_tmax40] 100 run(s) avg rewards : 2.5
# Point: 2.5
# Local runtime: 75.89971828460693 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 1500]	 rewards globals : 2.592 	avg rewards : 4.752,	avg loss: : 0.234028,	buffer size : 4000,	epsilon : 1.7%, 	 r <=40 23.762376237623762, 	 r > 40 0.0
# [Episode 1600]	 rewards globals : 2.730 	avg rewards : 4.752,	avg loss: : 0.237312,	buffer size : 4000,	epsilon : 1.5%, 	 r <=40 23.762376237623762, 	 r > 40 0.0
# [Episode 1700]	 rewards globals : 2.898 	avg rewards : 5.545,	avg loss: : 0.242118,	buffer size : 4000,	epsilon : 1.3%, 	 r <=40 27.722772277227726, 	 r > 40 0.0
# [Episode 1800]	 rewards globals : 3.071 	avg rewards : 5.941,	avg loss: : 0.250379,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 29.7029702970297, 	 r > 40 0.0
# [Episode 1900]	 rewards globals : 3.288 	avg rewards : 7.129,	avg loss: : 0.255228,	buffer size : 4000,	epsilon : 1.2%, 	 r <=40 35.64356435643564, 	 r > 40 0.0
# environment change : i_1 49 j_1 9
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 3.1
# [task_2_tmax40] 100 run(s) avg rewards : 3.4
# Point: 3.25
# Local runtime: 79.05858874320984 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 2000]	 rewards globals : 3.393 	avg rewards : 5.545,	avg loss: : 0.258345,	buffer size : 4000,	epsilon : 1.1%, 	 r <=40 27.722772277227726, 	 r > 40 0.0
# [Episode 2100]	 rewards globals : 3.489 	avg rewards : 5.347,	avg loss: : 0.262233,	buffer size : 4000,	epsilon : 1.1%, 	 r <=40 26.732673267326735, 	 r > 40 0.0
# [Episode 2200]	 rewards globals : 3.548 	avg rewards : 4.752,	avg loss: : 0.267543,	buffer size : 4000,	epsilon : 1.1%, 	 r <=40 23.762376237623762, 	 r > 40 0.0
# [Episode 2300]	 rewards globals : 3.664 	avg rewards : 6.139,	avg loss: : 0.272250,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 30.693069306930692, 	 r > 40 0.0
# [Episode 2400]	 rewards globals : 3.719 	avg rewards : 4.950,	avg loss: : 0.275964,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 24.752475247524753, 	 r > 40 0.0
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 2.9
# [task_2_tmax40] 100 run(s) avg rewards : 2.3
# Point: 2.5999999999999996
# Local runtime: 79.1645154953003 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 2500]	 rewards globals : 3.707 	avg rewards : 3.564,	avg loss: : 0.279231,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 17.82178217821782, 	 r > 40 0.0
# [Episode 2600]	 rewards globals : 3.795 	avg rewards : 5.941,	avg loss: : 0.282890,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 29.7029702970297, 	 r > 40 0.0
# [Episode 2700]	 rewards globals : 3.876 	avg rewards : 6.139,	avg loss: : 0.284619,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 30.693069306930692, 	 r > 40 0.0
# [Episode 2800]	 rewards globals : 3.945 	avg rewards : 5.743,	avg loss: : 0.285955,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 28.71287128712871, 	 r > 40 0.0
# [Episode 2900]	 rewards globals : 4.009 	avg rewards : 5.743,	avg loss: : 0.286976,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 28.71287128712871, 	 r > 40 0.0
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 2.2
# [task_2_tmax40] 100 run(s) avg rewards : 2.0
# Point: 2.1
# Local runtime: 72.82973408699036 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 3000]	 rewards globals : 4.069 	avg rewards : 5.743,	avg loss: : 0.287668,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 28.71287128712871, 	 r > 40 0.0
# [Episode 3100]	 rewards globals : 4.118 	avg rewards : 5.545,	avg loss: : 0.288469,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 27.722772277227726, 	 r > 40 0.0
# [Episode 3200]	 rewards globals : 4.177 	avg rewards : 6.139,	avg loss: : 0.288314,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 30.693069306930692, 	 r > 40 0.0
# [Episode 3300]	 rewards globals : 4.262 	avg rewards : 6.931,	avg loss: : 0.288808,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 34.65346534653465, 	 r > 40 0.0
# [Episode 3400]	 rewards globals : 4.302 	avg rewards : 5.545,	avg loss: : 0.290441,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 27.722772277227726, 	 r > 40 0.0
# Test mode, runs: 100, i: 49, j: 9, final: True
# [task_2_tmax50] 100 run(s) avg rewards : 3.3
# [task_2_tmax40] 100 run(s) avg rewards : 1.9
# Point: 2.5999999999999996
# Local runtime: 71.29720306396484 seconds --- fast
# WARNING: do note that this might not reflect the runtime on the server.
# [Episode 3500]	 rewards globals : 4.344 	avg rewards : 5.743,	avg loss: : 0.292797,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 28.71287128712871, 	 r > 40 0.0
# [Episode 3600]	 rewards globals : 4.352 	avg rewards : 4.554,	avg loss: : 0.294948,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 22.772277227722775, 	 r > 40 0.0
# [Episode 3700]	 rewards globals : 4.369 	avg rewards : 5.149,	avg loss: : 0.297582,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 25.742574257425744, 	 r > 40 0.0
# [Episode 3800]	 rewards globals : 4.349 	avg rewards : 3.564,	avg loss: : 0.299457,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 17.82178217821782, 	 r > 40 0.0
# [Episode 3900]	 rewards globals : 4.381 	avg rewards : 5.545,	avg loss: : 0.300994,	buffer size : 4000,	epsilon : 1.0%, 	 r <=40 27.722772277227726, 	 r > 40 0.0
# 13274.259229183197

# %%
# Test for TASK 2:
from google.colab import files
# !apt-get install zip
# !zip -r HW3_Task2.zip HW3_Task2
files.download('HW3_Task2.zip')
# Out:
# Reading package lists... Done
# ^C
#   adding: HW3_Task2/ (stored 0%)
#   adding: HW3_Task2/agent/ (stored 0%)
#   adding: HW3_Task2/agent/model_cb_19_19_55_45_49_7.pt (deflated 8%)
#   adding: HW3_Task2/agent/env.py (deflated 71%)
#   adding: HW3_Task2/agent/__pycache__/ (stored 0%)
#   adding: HW3_Task2/agent/__pycache__/env.cpython-36.pyc (deflated 39%)
#   adding: HW3_Task2/agent/__init__.py (deflated 64%)
#   adding: HW3_Task2/agent/models.py (deflated 70%)
#   adding: HW3_Task2/agent/.ipynb_checkpoints/ (stored 0%)
#   adding: HW3_Task2/setup.py (deflated 27%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-8d6180681604> in <module>()
#       2 get_ipython().system('apt-get install zip')
#       3 get_ipython().system('zip -r HW3_Task2.zip HW3_Task2')
# ----> 4 files.download('HW3_Task2.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
# TASK 1

import time
duree = 0 
nb_bad_init = 0 
# Try for 10 diferent inits

for i in range(0,10):
  debut = time.time()
  # Try an init 
  # !python3 HW3_Task1/agent/dqn.py --train
  duree = (time.time()-debut)
  # If good init exit loop
  if duree > 100:
    break
# Out:
# python3: can't open file 'HW3_Task1/agent/dqn.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-c525fe8926e1> in <module>()
#       8   debut = time.time()
#       9   # Try an init
# ---> 10   get_ipython().system('python3 HW3_Task1/agent/dqn.py --train')
#      11   duree = (time.time()-debut)
#      12   # If good init exit loop
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      94       kwargs.update({'also_return_output': True})
#      95
# ---> 96     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      97
#      98     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     353
#     354   hide_args = ['cell_remove_stdin', {}]
# --> 355   _message.blocking_request(*hide_args, parent=shell.parent_header)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
from HW3_Task2.agent.env import construct_task2_env_0
import numpy as np
env = construct_task2_env_0()

state = env.reset()
env.render()
#for i in range(0,10):
#  env.step(1)
#  env.render()
def pos_from_state(state):
  for i in range(0,10):
    column = (np.where(state[1,i,:] == 1.))
    if len(column[0]) > 0:
      column = column[0][0]
      row = i 
      return(column,row)

def state_from_pos(pos_x,pos_y,state):
  #Crop to keep a window [49,4]
  if pos_y > 8:
    y_max = 9
    y_min = 5
  elif pos_y < 2:
    y_max = 4
    y_min = 0
  else:
    y_max = pos_y + 2
    y_min = pos_y - 2

  return(state[:,y_min:(y_max+1),x_min:(x_max+1)])

pos_y,pos_x = pos_from_state(state)
print(pos_x,pos_y)
next_state = state_from_pos(pos_x,pos_y,state)
print(next_state)

#print(next_state)
# Out:
# ========================================================================================================================================================================================================
#   F   -   -   2   -   -   -   3   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   1   -   -   O   4   -   -   6   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   5   -
#   -   -   -   -  14   -   -   -   -   -   -  11   -   -   -   -   -   -   -   -   -   -   -   -   -  10   -   -   -   -   -   -   9   -   8   -   7   -  12   -  13   -   -   -   -   -   -   -   -   -
#   -   -   -   -   -  19   -   -   -   -   -   -   -   -   -   -   -  20   -   -   -   -   -   -   -  18   -   -   -   -  16   -   -   -   -   -   -   -  15   -   -  17   -   -   -   -   -   -   -   -
#   -   -   -   -   -  21   -   -   -  24   -   -   -   -   -  25   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  26   -  23   -   -   -   -   -   -   -   -   -   -  22   -   -   -
#  32   -  29   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  33   -   -   -   -   -   -   -   -  27   -   -   -   -   -   -   -  31  30   -   -   -   -   -   -  28   -   -
#  35  40   -   -   -   -   -   -   -   -  36   -   -   -  39   -   -   -   -   -   -   -   -   -  37   -   -   -   -   -   -   -   -   -   -   -   -   -   -  34   -   -  41   -   -   -   -  38   -   -
#  47   -   -  45   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  43  42   -   -   -   -   -   -   -   -   -   -   -   -  44   -   -   -   -  46   -   -
#   -   -   -   -   -   -   -  48   -   -   -   -   -  50   -   -   -  53   -   -   -   -   -   -   -   -   -   -   -   -   -   -  52  54   -   -   -   -   -   -   -  51  49   -   -   -   -   -   -   -
#   -   -   -   -  60   -   -   -   -   -   -   -   -  55   -   -   -  58   -   -  56   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -   -  59   -  57   -   -   -   -   -   -   -
#  62   -   -   -   -   -  65   -   -   -  63   -   -  66   -   -   -  67   -   -   -   -   -  61   -   -   -   -   -   -   -   -   -  64   -   -   -   -   -   -   -   -   -   -   -   -   -  68   -   <
# ========================================================================================================================================================================================================
# 9 49
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-a4469bff43c5> in <module>()
#      32 pos_y,pos_x = pos_from_state(state)
#      33 print(pos_x,pos_y)
# ---> 34 next_state = state_from_pos(pos_x,pos_y,state)
#      35 print(next_state)
#      36
#
# <ipython-input-49-a4469bff43c5> in state_from_pos(pos_x, pos_y, state)
#      28     y_min = pos_y - 2
#      29
# ---> 30   return(state[:,y_min:(y_max+1),x_min:(x_max+1)])
#      31
#      32 pos_y,pos_x = pos_from_state(state)
#
# NameError: name 'x_min' is not defined
